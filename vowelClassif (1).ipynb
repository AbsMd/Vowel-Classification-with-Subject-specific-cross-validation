# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install --upgrade keras

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D
from keras.layers import Activation, Dropout, Dense, Flatten, BatchNormalization
from keras.layers import LSTM, GRU, Bidirectional
from tensorflow.keras import activations, regularizers
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# Loading data

# %%
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S1/S1a.csv'
i1 = pd.read_csv(path, header=None)
i1 = i1.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S1/S1e.csv'
i2 = pd.read_csv(path, header=None)
i2 = i2.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S1/S1i.csv'
i3 = pd.read_csv(path, header=None)
i3 = i3.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S1/S1o.csv'
i4 = pd.read_csv(path, header=None)
i4 = i4.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S1/S1u.csv'
i5 = pd.read_csv(path, header=None)
i5 = i5.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S2/S2a.csv'
i6 = pd.read_csv(path, header=None)
i6 = i6.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S2/S2e.csv'
i7 = pd.read_csv(path, header=None)
i7 = i7.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S2/S2i.csv'
i8 = pd.read_csv(path, header=None)
i8 = i8.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S2/S2o.csv'
i9 = pd.read_csv(path, header=None)
i9 = i9.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S2/S2u.csv'
i10 = pd.read_csv(path, header=None)
i10 = i10.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S3/S3a.csv'
i11 = pd.read_csv(path, header=None)
i11 = i11.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S3/S3e.csv'
i12 = pd.read_csv(path, header=None)
i12 = i12.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S3/S3i.csv'
i13 = pd.read_csv(path, header=None)
i13 = i13.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S3/S3o.csv'
i14 = pd.read_csv(path, header=None)
i14 = i14.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S3/S3u.csv'
i15 = pd.read_csv(path, header=None)
i15 = i15.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S4/S4a.csv'
i16 = pd.read_csv(path, header=None)
i16 = i16.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S4/S4e.csv'
i17 = pd.read_csv(path, header=None)
i17 = i17.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S4/S4i.csv'
i18 = pd.read_csv(path, header=None)
i18 = i18.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S4/S4o.csv'
i19 = pd.read_csv(path, header=None)
i19 = i19.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S4/S4u.csv'
i20 = pd.read_csv(path, header=None)
i20 = i20.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S5/S5a.csv'
i21 = pd.read_csv(path, header=None)
i21 = i21.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S5/S5e.csv'
i22 = pd.read_csv(path, header=None)
i22 = i22.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S5/S5i.csv'
i23 = pd.read_csv(path, header=None)
i23 = i23.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S5/S5o.csv'
i24 = pd.read_csv(path, header=None)
i24 = i24.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S5/S5u.csv'
i25 = pd.read_csv(path, header=None)
i25 = i25.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S6/S6a.csv'
i26 = pd.read_csv(path, header=None)
i26 = i26.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S6/S6e.csv'
i27 = pd.read_csv(path, header=None)
i27 = i27.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S6/S6i.csv'
i28 = pd.read_csv(path, header=None)
i28 = i28.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S6/S6o.csv'
i29 = pd.read_csv(path, header=None)
i29 = i29.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S6/S6u.csv'
i30 = pd.read_csv(path, header=None)
i30 = i30.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S7/S7a.csv'
i31 = pd.read_csv(path, header=None)
i31 = i31.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S7/S7e.csv'
i32 = pd.read_csv(path, header=None)
i32 = i32.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S7/S7i.csv'
i33 = pd.read_csv(path, header=None)
i33 = i33.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S7/S7o.csv'
i34 = pd.read_csv(path, header=None)
i34 = i34.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S7/S7u.csv'
i35 = pd.read_csv(path, header=None)
i35 = i35.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S8/S8a.csv'
i36 = pd.read_csv(path, header=None)
i36 = i36.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S8/S8e.csv'
i37 = pd.read_csv(path, header=None)
i37 = i37.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S8/S8i.csv'
i38 = pd.read_csv(path, header=None)
i38 = i38.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S8/S8o.csv'
i39 = pd.read_csv(path, header=None)
i39 = i39.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S8/S8u.csv'
i40 = pd.read_csv(path, header=None)
i40 = i40.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S9/S9a.csv'
i41 = pd.read_csv(path, header=None)
i41 = i41.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S9/S9e.csv'
i42 = pd.read_csv(path, header=None)
i42 = i42.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S9/S9i.csv'
i43 = pd.read_csv(path, header=None)
i43 = i43.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S9/S9o.csv'
i44 = pd.read_csv(path, header=None)
i44 = i44.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S9/S9u.csv'
i45 = pd.read_csv(path, header=None)
i45 = i45.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S10/S10a.csv'
i46 = pd.read_csv(path, header=None)
i46 = i46.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S10/S10e.csv'
i47 = pd.read_csv(path, header=None)
i47 = i47.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S10/S10i.csv'
i48 = pd.read_csv(path, header=None)
i48 = i48.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S10/S10o.csv'
i49 = pd.read_csv(path, header=None)
i49 = i49.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S10/S10u.csv'
i50 = pd.read_csv(path, header=None)
i50 = i50.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S11/S11a.csv'
i51 = pd.read_csv(path, header=None)
i51 = i51.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S11/S11e.csv'
i52 = pd.read_csv(path, header=None)
i52 = i52.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S11/S11i.csv'
i53 = pd.read_csv(path, header=None)
i53 = i53.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S11/S11o.csv'
i54 = pd.read_csv(path, header=None)
i54 = i54.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S11/S11u.csv'
i55 = pd.read_csv(path, header=None)
i55 = i55.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S12/S12a.csv'
i56 = pd.read_csv(path, header=None)
i56 = i56.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S12/S12e.csv'
i57 = pd.read_csv(path, header=None)
i57 = i57.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S12/S12i.csv'
i58 = pd.read_csv(path, header=None)
i58 = i58.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S12/S12o.csv'
i59 = pd.read_csv(path, header=None)
i59 = i59.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S12/S12u.csv'
i60 = pd.read_csv(path, header=None)
i60 = i60.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S13/S13a.csv'
i61 = pd.read_csv(path, header=None)
i61 = i61.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S13/S13e.csv'
i62 = pd.read_csv(path, header=None)
i62 = i62.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S13/S13i.csv'
i63 = pd.read_csv(path, header=None)
i63 = i63.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S13/S13o.csv'
i64 = pd.read_csv(path, header=None)
i64 = i64.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S13/S13u.csv'
i65 = pd.read_csv(path, header=None)
i65 = i65.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S14/S14a.csv'
i66 = pd.read_csv(path, header=None)
i66 = i66.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S14/S14e.csv'
i67 = pd.read_csv(path, header=None)
i67 = i67.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S14/S14i.csv'
i68 = pd.read_csv(path, header=None)
i68 = i68.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S14/S14o.csv'
i69 = pd.read_csv(path, header=None)
i69 = i69.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S14/S14u.csv'
i70 = pd.read_csv(path, header=None)
i70 = i70.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S15/S15a.csv'
i71 = pd.read_csv(path, header=None)
i71 = i71.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S15/S15e.csv'
i72 = pd.read_csv(path, header=None)
i72 = i72.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S15/S15i.csv'
i73 = pd.read_csv(path, header=None)
i73 = i73.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S15/S15o.csv'
i74 = pd.read_csv(path, header=None)
i74 = i74.to_numpy()
path = '/content/drive/MyDrive/BITS/4-1/Projects/misc/tensors/xlsx/S15/S15u.csv'
i75 = pd.read_csv(path, header=None)
i75 = i75.to_numpy()
del path,

# %%
size = []
size.append(i1.shape[0])
print(size)
size.append(i2.shape[0])
size.append(i3.shape[0])
size.append(i4.shape[0])
size.append(i5.shape[0])
size.append(i6.shape[0])
size.append(i7.shape[0])
size.append(i8.shape[0])
size.append(i9.shape[0])
size.append(i10.shape[0])
size.append(i11.shape[0])
size.append(i12.shape[0])
size.append(i13.shape[0])
size.append(i14.shape[0])
size.append(i15.shape[0])
size.append(i16.shape[0])
size.append(i17.shape[0])
size.append(i18.shape[0])
size.append(i19.shape[0])
size.append(i20.shape[0])
size.append(i21.shape[0])
size.append(i22.shape[0])
size.append(i23.shape[0])
size.append(i24.shape[0])
size.append(i25.shape[0])
size.append(i26.shape[0])
size.append(i27.shape[0])
size.append(i28.shape[0])
size.append(i29.shape[0])
size.append(i30.shape[0])
size.append(i31.shape[0])
size.append(i32.shape[0])
size.append(i33.shape[0])
size.append(i34.shape[0])
size.append(i35.shape[0])
size.append(i36.shape[0])
size.append(i37.shape[0])
size.append(i38.shape[0])
size.append(i39.shape[0])
size.append(i40.shape[0])
size.append(i41.shape[0])
size.append(i42.shape[0])
size.append(i43.shape[0])
size.append(i44.shape[0])
size.append(i45.shape[0])
size.append(i46.shape[0])
size.append(i47.shape[0])
size.append(i48.shape[0])
size.append(i49.shape[0])
size.append(i50.shape[0])
size.append(i51.shape[0])
size.append(i52.shape[0])
size.append(i53.shape[0])
size.append(i54.shape[0])
size.append(i55.shape[0])
size.append(i56.shape[0])
size.append(i57.shape[0])
size.append(i58.shape[0])
size.append(i59.shape[0])
size.append(i60.shape[0])
size.append(i61.shape[0])
size.append(i62.shape[0])
size.append(i63.shape[0])
size.append(i64.shape[0])
size.append(i65.shape[0])
size.append(i66.shape[0])
size.append(i67.shape[0])
size.append(i68.shape[0])
size.append(i69.shape[0])
size.append(i70.shape[0])
size.append(i71.shape[0])
size.append(i72.shape[0])
size.append(i73.shape[0])
size.append(i74.shape[0])
size.append(i75.shape[0])
# Out:
# [286720]

# %%
l = 4096
m = 30
n = 15
s = []
for i in range(5*n):
  s.append(int(size[i]/l))
print(s)
# Out:
# [70, 63, 67, 66, 65, 56, 56, 56, 56, 56, 55, 56, 57, 58, 55, 52, 55, 55, 52, 52, 54, 54, 53, 51, 55, 55, 55, 50, 54, 56, 56, 48, 50, 51, 52, 56, 54, 56, 54, 57, 60, 60, 62, 60, 61, 58, 56, 58, 55, 57, 55, 56, 55, 56, 56, 56, 55, 55, 55, 55, 55, 53, 55, 55, 56, 57, 57, 57, 58, 56, 56, 55, 57, 50, 55]

# %%
i1 = i1.reshape((s[0],l,m))
i2 = i2.reshape((s[1],l,m))
i3 = i3.reshape((s[2],l,m))
i4 = i4.reshape((s[3],l,m))
i5 = i5.reshape((s[4],l,m))
i6 = i6.reshape((s[5],l,m))
i7 = i7.reshape((s[6],l,m))
i8 = i8.reshape((s[7],l,m))
i9 = i9.reshape((s[8],l,m))
i10 = i10.reshape((s[9],l,m))
i11 = i11.reshape((s[10],l,m))
i12 = i12.reshape((s[11],l,m))
i13 = i13.reshape((s[12],l,m))
i14 = i14.reshape((s[13],l,m))
i15 = i15.reshape((s[14],l,m))
i16 = i16.reshape((s[15],l,m))
i17 = i17.reshape((s[16],l,m))
i18 = i18.reshape((s[17],l,m))
i19 = i19.reshape((s[18],l,m))
i20 = i20.reshape((s[19],l,m))
i21 = i21.reshape((s[20],l,m))
i22 = i22.reshape((s[21],l,m))
i23 = i23.reshape((s[22],l,m))
i24 = i24.reshape((s[23],l,m))
i25 = i25.reshape((s[24],l,m))
i26 = i26.reshape((s[25],l,m))
i27 = i27.reshape((s[26],l,m))
i28 = i28.reshape((s[27],l,m))
i29 = i29.reshape((s[28],l,m))
i30 = i30.reshape((s[29],l,m))
i31 = i31.reshape((s[30],l,m))
i32 = i32.reshape((s[31],l,m))
i33 = i33.reshape((s[32],l,m))
i34 = i34.reshape((s[33],l,m))
i35 = i35.reshape((s[34],l,m))
i36 = i36.reshape((s[35],l,m))
i37 = i37.reshape((s[36],l,m))
i38 = i38.reshape((s[37],l,m))
i39 = i39.reshape((s[38],l,m))
i40 = i40.reshape((s[39],l,m))
i41 = i41.reshape((s[40],l,m))
i42 = i42.reshape((s[41],l,m))
i43 = i43.reshape((s[42],l,m))
i44 = i44.reshape((s[43],l,m))
i45 = i45.reshape((s[44],l,m))
i46 = i46.reshape((s[45],l,m))
i47 = i47.reshape((s[46],l,m))
i48 = i48.reshape((s[47],l,m))
i49 = i49.reshape((s[48],l,m))
i50 = i50.reshape((s[49],l,m))
i51 = i51.reshape((s[50],l,m))
i52 = i52.reshape((s[51],l,m))
i53 = i53.reshape((s[52],l,m))
i54 = i54.reshape((s[53],l,m))
i55 = i55.reshape((s[54],l,m))
i56 = i56.reshape((s[55],l,m))
i57 = i57.reshape((s[56],l,m))
i58 = i58.reshape((s[57],l,m))
i59 = i59.reshape((s[58],l,m))
i60 = i60.reshape((s[59],l,m))
i61 = i61.reshape((s[60],l,m))
i62 = i62.reshape((s[61],l,m))
i63 = i63.reshape((s[62],l,m))
i64 = i64.reshape((s[63],l,m))
i65 = i65.reshape((s[64],l,m))
i66 = i66.reshape((s[65],l,m))
i67 = i67.reshape((s[66],l,m))
i68 = i68.reshape((s[67],l,m))
i69 = i69.reshape((s[68],l,m))
i70 = i70.reshape((s[69],l,m))
i71 = i71.reshape((s[70],l,m))
i72 = i72.reshape((s[71],l,m))
i73 = i73.reshape((s[72],l,m))
i74 = i74.reshape((s[73],l,m))
i75 = i75.reshape((s[74],l,m))

# %%
y = []
for i in range(5*n):
  for j in range(s[i]):
    y.append(i%5)
y = np.asarray(y)

# %%
X_test = np.concatenate([i1, i2, i3, i4, i5], axis=0)
del i1, i2, i3, i4, i5
X_train = np.concatenate([i6, i7, i8, i9, i10], axis=0)
del i6, i7, i8, i9, i10
X_train = np.concatenate([X_train, i11, i12, i13, i14, i15, i16, i17, i18, i19, i20], axis=0)
del i11, i12, i13, i14, i15, i16, i17, i18, i19, i20
X_train = np.concatenate([X_train, i21, i22, i23, i24, i25, i26, i27, i28, i29, i30], axis=0)
del i21, i22, i23, i24, i25, i26, i27, i28, i29, i30
X_train = np.concatenate([X_train, i31, i32, i33, i34, i35, i36, i37, i38, i39, i40], axis=0)
del i31, i32, i33, i34, i35, i36, i37, i38, i39, i40
X_train = np.concatenate([X_train, i41, i42, i43, i44, i45, i46, i47, i48, i49, i50], axis=0)
del i41, i42, i43, i44, i45, i46, i47, i48, i49, i50
X_train = np.concatenate([X_train, i51, i52, i53, i54, i55, i56, i57, i58, i59, i60], axis=0)
del i51, i52, i53, i54, i55, i56, i57, i58, i59, i60
X_train = np.concatenate([X_train, i61, i62, i63, i64, i65, i66, i67, i68, i69, i70], axis=0)
del i61, i62, i63, i64, i65, i66, i67, i68, i69, i70
X_train = np.concatenate([X_train, i71, i72, i73, i74, i75], axis=0)
del i71, i72, i73, i74, i75

# %%
from sklearn.model_selection import train_test_split
print(X_test.shape)
print(X_train.shape)
print(y.shape)

a = X_test.shape[0]

y = to_categorical(y, num_classes=5)

#os.environ['TF_CPP_MIN_LOG_LEVEL'] = '5'
y_test = y[:a]
y_train = y[a:]
X_train,X_valid,y_train,y_valid = train_test_split(X_train,y_train,test_size=1/8,train_size=4/8,random_state=0)
del y

print(y_train.shape)
print(y_test.shape)
print(X_valid.shape)
print(y_valid.shape)
# Out:
# (331, 4096, 30)
# (3871, 4096, 30)
# (4202,)
# (1935, 5)
# (331, 5)
# (484, 4096, 30)
# (484, 5)

# %%
model = Sequential()
model.add(Conv1D(kernel_size=10, filters=20, activation='relu', input_shape=(l,30)))
model.add(BatchNormalization())
model.add(MaxPooling1D(pool_size=3, strides=3))
model.add(Activation("relu"))
model.add(Dropout(0.7))
model.add(Bidirectional(LSTM(64)))
model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.0001, l2=0.001)))
model.add(Dropout(0.7))
model.add(Dense(32, activation='relu', kernel_regularizer=regularizers.l1_l2(l1=0.0001, l2=0.001)))
model.add(Dropout(0.5))
model.add(Dense(5,activation="softmax"))
opt = keras.optimizers.Adam(learning_rate = 0.0001)
model.compile(optimizer = opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history=model.fit(X_train, y_train, epochs=100, batch_size=100, validation_data=(X_valid,y_valid),)
print(history)
loss, acc = model.evaluate(X_train,y_train)

plt.subplot(221)
plt.plot(history.history['loss'], color='r', label='loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.subplot(222)
plt.plot(history.history['val_loss'], color='b', label=' val_loss')
plt.title('Val Loss')
plt.xlabel('Epochs')
plt.subplot(223)
plt.plot(history.history['accuracy'], color='b', label='acc')
plt.title('Model Acc')
plt.xlabel('Epochs')
plt.subplot(224)
plt.plot(history.history['val_accuracy'], color='b', label=' val_acc')
plt.title('Val acc')
plt.xlabel('Epochs')
plt.show()

print("Overall accuracy: ", history.history['accuracy'][-1]*100, '%')
print("Validation accuracy: ", history.history['val_accuracy'][-1]*100, '%')

score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', (score[1]*100), '%')
# Out:
# Epoch 1/100
# 20/20 [==============================] - 68s 3s/step - loss: 2.0431 - accuracy: 0.2109 - val_loss: 1.9719 - val_accuracy: 0.2066
# Epoch 2/100
# 20/20 [==============================] - 61s 3s/step - loss: 2.0135 - accuracy: 0.2088 - val_loss: 1.9640 - val_accuracy: 0.2066
# Epoch 3/100
# 20/20 [==============================] - 60s 3s/step - loss: 2.0049 - accuracy: 0.2088 - val_loss: 1.9610 - val_accuracy: 0.1963
# Epoch 4/100
# 20/20 [==============================] - 61s 3s/step - loss: 1.9928 - accuracy: 0.2016 - val_loss: 1.9583 - val_accuracy: 0.1921
# Epoch 5/100
# 20/20 [==============================] - 60s 3s/step - loss: 2.0007 - accuracy: 0.2124 - val_loss: 1.9558 - val_accuracy: 0.1921
# Epoch 6/100
# 20/20 [==============================] - 60s 3s/step - loss: 1.9853 - accuracy: 0.2171 - val_loss: 1.9539 - val_accuracy: 0.1860
# Epoch 7/100
# ...
